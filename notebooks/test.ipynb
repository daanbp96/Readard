# %%
from pathlib import Path

from app.session import ReadingSession
from app.environment import (
    DATA_DIR,
    initialize_environment,
)
from app.config import LLM_PROVIDER, OPENAI_MODEL
from app.llm import create_llm

# %%
BOOK_NAME = "Harry Potter and the Sorcerer's Stone.epub"


initialize_environment()
llm = create_llm(model=OPENAI_MODEL, provider=LLM_PROVIDER)

session = ReadingSession(llm=llm)

session.load_book(DATA_DIR / BOOK_NAME)

# %%
LAST_READ_SENTENCE = "Oh, it was nothing, dear"

session.set_position(LAST_READ_SENTENCE)
# Out:
# ResolvedPosition(snippet='Oh, it was nothing, dear', normalized_snippet='Oh, it was nothing, dear', spine_idx=3, local_plain_offset=102038, reader_boundary_key='00030000102038')

# %%
QUERY = "from what chapter is this"

print(session.ask(QUERY))
# Out:
# The passage you provided is from Chapter Twelve, titled "The Mirror of Erised." This is evident because it describes Harry's Christmas at the Burrow, receiving the invisibility cloak, and his subsequent visit to the Restricted Section of the library at night, where he discovers the Mirror of Erised.
